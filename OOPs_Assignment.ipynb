# %% [markdown]
#           **Python OOPs**

# %% [markdown]
#          **Python OOPs Questions**
#
# 1. What is Object-Oriented Programming (OOP)?
#
# ->  Object-Oriented Programming (OOP) is a programming paradigm that organizes software design around objects, rather than functions or logic.
# An object is a real-world entity that has data (attributes) and behavior (methods).
#
# 2.  What is a class in OOP?
#
# -> In Object-Oriented Programming (OOP), a class is a blueprint or template for creating objects.
#
# It defines the attributes (data) and methods (functions) that describe the behavior and properties of the objects created from it.
#
#
# 3. What is an object in OOP?
#
# -> In Object-Oriented Programming (OOP), an object is an instance of a class.
#
# It represents a real-world entity that has data (attributes) and behavior (methods) defined by its class.
#
# 4.  What is the difference between abstraction and encapsulation?
#
# -> Both abstraction and encapsulation are key concepts in Object-Oriented Programming (OOP) — but they serve different purposes.
#
# Here’s a clear comparison 👇
#
# | Feature         | **Abstraction**                                                                | **Encapsulation**                                                            |
# | --------------- | ------------------------------------------------------------------------------ | ---------------------------------------------------------------------------- |
# | **Meaning**     | Hides *implementation details* and shows *only essential features*.            | Hides *data* by bundling it with methods that control access.                |
# | **Focus**       | Focuses on *what* an object does.                                              | Focuses on *how* data is protected.                                          |
# | **Purpose**     | To simplify complex systems by showing only necessary parts.                   | To protect data from unauthorized access or modification.                    |
# | **Achieved by** | Using **abstract classes** or **interfaces**.                                  | Using **private/public/protected access modifiers** and **getters/setters**. |
# | **Example**     | You can drive a car without knowing how its engine works — that’s abstraction. | The car’s engine details are hidden inside — that’s encapsulation.           |
#
# 5. What are dunder methods in Python?
#
# -> In Python, dunder methods (short for “double underscore” methods) are special built-in methods that start and end with double underscores (__).
#
# They are also called magic methods because they allow you to customize how objects behave with built-in operations (like printing, addition, comparison, etc.).
#
# 6. Explain the concept of inheritance in OOP.
#
# -> . In Object-Oriented Programming (OOP), inheritance is a mechanism that allows one class to acquire the properties and behaviors (attributes and methods) of another class.
#
# . It helps in code reusability and represents an “is-a” relationship between classes.
#
# 7.  What is polymorphism in OOP?
#
#  -> Polymorphism in Object-Oriented Programming (OOP) means "many forms" — it allows the same function, method, or operator to behave differently based on the object it is acting upon.
#
# In simple terms, the same operation can behave differently for different classes.
#
# 8.  How is encapsulation achieved in Python?
#
#  -> Encapsulation in Python is the process of restricting direct access to an object’s data (variables) and methods, and controlling it through public, protected, or private access levels.
# It helps in data hiding and protecting the internal state of an object.
#
# 9. What is a constructor in Python?
#
# -> A constructor in Python is a special method used to initialize objects when a class is instantiated.
# It allows you to set up initial values for the object’s attributes automatically when you create it.
#
#
# 10. What are class and static methods in Python?
#
# -> In Python, class methods and static methods are two special types of methods used inside a class — both are not the same as normal instance methods.
#
# Let’s understand both clearly 👇
#
# 🔹 1. Instance Method (Default)
#
# ✅ Regular method that operates on a specific object (instance) of the class.
# ✅ It can access and modify instance variables.
#
# 🔹 2. Class Method
#
# ✅ Defined using the @classmethod decorator.
# ✅ Takes cls as the first parameter (refers to the class, not an instance).
# ✅ Can access or modify class-level variables but not instance variables directly.
#
# 11. What is method overloading in Python?
#
# -> Method Overloading in Python refers to defining multiple methods with the same name but different parameters — however, Python does not support true method overloading like Java or C++.
#
# 👉 In Python, the latest defined method overrides the previous ones.
# But we can simulate overloading using default parameters or *args (variable arguments).
#
# 12. What is method overriding in OOP?
#
# ->Method Overriding in Object-Oriented Programming (OOP) occurs when a child (subclass) defines a method with the same name and parameters as a method in its parent (superclass) — but provides a different implementation.
#
# 👉 It allows a subclass to customize or replace behavior inherited from the parent class.
#
# 🔹 Key Idea
#
# . Same method name and parameters
#
# . Defined in both parent and child classes
#
# . The child class method overrides the parent class method during runtime
#
# 13. What is a property decorator in Python?
#
# -> The @property decorator in Python is used to turn a class method into a “getter”, allowing you to access it like an attribute — without calling it like a function.
#
# It is mainly used to control access to instance variables (data encapsulation) while keeping a clean, attribute-like interface.
#
# 14.  Why is polymorphism important in OOP?
#
# -> Polymorphism is important in Object-Oriented Programming (OOP) because it makes programs more flexible, reusable, and maintainable.
#
# It allows one interface to be used for different types of objects, making your code easier to extend and modify without breaking existing functionality.
#
# 🔹 Main Reasons Why Polymorphism Is Important
# 1. Code Reusability
#
# You can write one function or method that works with different object types, instead of duplicating code for each class.
#
# 👉 Example:
#
# class Dog:
#     def speak(self):
#         return "Bark"
#
# class Cat:
#     def speak(self):
#         return "Meow"
#
# def make_sound(animal):
#     print(animal.speak())
#
# make_sound(Dog())  # Output: Bark
# make_sound(Cat())  # Output: Meow
#
# ✅ The same make_sound() function works for both Dog and Cat.
#
# 2. Flexibility and Extensibility
#
# You can add new classes (e.g., Cow, Lion) without changing existing code.
# Just define a speak() method, and they’ll work automatically with make_sound().
#
# 👉 You can extend the system easily — that’s open/closed principle in action (open for extension, closed for modification).
#
#
# 15. What is an abstract class in Python?
#
# -> An abstract class in Python is a blueprint for other classes — it defines a common structure that its subclasses must follow, but it cannot be instantiated (you can’t create an object directly from it).
#
# It is mainly used to enforce certain methods in all subclasses — ensuring they provide specific behavior.
#
# 🔹 Key Points:
#
# . Defined using the abc module (Abstract Base Classes).
#
# . You use the decorator @abstractmethod to declare abstract methods.
#
# . Subclasses must override all abstract methods, otherwise they can’t be instantiated.
#
# . Promotes polymorphism and code consistency.
#
# 16. What are the advantages of OOP?
#
# -> An abstract class in Python is a blueprint for other classes — it defines a common structure that its subclasses must follow, but it cannot be instantiated (you can’t create an object directly from it).
#
# It is mainly used to enforce certain methods in all subclasses — ensuring they provide specific behavior.
#
# 🔹 Key Points:
#
# . Defined using the abc module (Abstract Base Classes).
#
# . You use the decorator @abstractmethod to declare abstract methods.
#
# . Subclasses must override all abstract methods, otherwise they can’t be instantiated.
#
# . Promotes polymorphism and code consistency.
#
# 17. What is the difference between a class variable and an instance variable?
#
# -> The main difference between a class variable and an instance variable in Python lies in how and where the data is stored and shared among objects.
#
# Let’s break it down 👇
#
# 🔹 1. Instance Variable
#
# . Defined inside the constructor (__init__).
#
# . Belongs to a specific object (instance).
#
# . Each object has its own copy of the variable.
#
# . Changing one object’s instance variable does not affect others.
#
# 🔹 2. Class Variable
#
# . Defined outside any method, usually directly inside the class.
#
# . Belongs to the class itself, not to any one object.
#
# . Shared by all instances of the class.
#
# . Changing it using the class name affects all objects.
#
#
# | Feature              | **Class Variable**                                             | **Instance Variable**                                                           |
# | -------------------- | -------------------------------------------------------------- | ------------------------------------------------------------------------------- |
# | **Definition**       | Defined **inside the class**, but **outside any method**.      | Defined **inside the `__init__` method** (or any instance method) using `self`. |
# | **Belongs to**       | The **class** — shared by all instances of the class.          | The **object (instance)** — each object has its own copy.                       |
# | **Accessed by**      | Accessed using either the **class name** or **instance name**. | Accessed using **`self.variable_name`**.                                        |
# | **Shared or Unique** | **Shared** among all instances. Changes affect all objects.    | **Unique** to each instance. Changes affect only that object.                   |
# | **Example**          |                                                                |                                                                                 |
#
# 18.  What is multiple inheritance in Python?
#
# -> Multiple inheritance in Python means that a class can inherit from more than one parent class.
# In simple words — a child class can have multiple base classes, and it will inherit attributes and methods from all of them.
#
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python.
#
# -> In Python, the __str__ and __repr__ methods are special (dunder) methods used to define how an object is represented as a string.
# They are mainly used for displaying objects in a readable or unambiguous way.
#
# Let’s break them down 👇
#
# 🧩 1. __str__() – User-friendly representation
#
# . The __str__ method is called when you use the print() function or str() on an object.
#
# . It is meant to return a human-readable, friendly description of the object.
#
# 20. What is the significance of the ‘super()’ function in Python?
#
# -> The super() function in Python is used to call methods from a parent (super) class inside a child (derived) class.
#
# It’s especially useful in inheritance, allowing the child class to reuse code from its parent class without naming the parent class explicitly.
#
# 🧠 Purpose of super()
#
# . To access parent class methods or attributes inside a subclass.
#
# . To avoid repeating parent class names, which makes code easier to maintain.
#
# . To ensure proper method resolution in multiple inheritance (Python follows MRO – Method Resolution Order).
#
# 21. What is the significance of the __del__ method in Python?
#
# -> The __del__() method in Python is a destructor — it is called automatically when an object is about to be destroyed (i.e., when it goes out of scope or its reference count becomes zero).
#
# It is used to clean up resources like closing files, releasing memory, or disconnecting network connections before the object is deleted.
#
# 🧠 Purpose of __del__()
#
# . To perform cleanup actions before an object is removed from memory.
#
# . To release external resources (files, database connections, sockets, etc.) safely.
#
# 22.  What is the difference between @staticmethod and @classmethod in Python?
#
# -> | Feature                     | `@staticmethod`                        | `@classmethod`                         |
# | --------------------------- | -------------------------------------- | -------------------------------------- |
# | First argument              | No default argument                    | `cls` (represents class)               |
# | Access to class (`cls`)     | ❌ No                                   | ✅ Yes                                  |
# | Access to instance (`self`) | ❌ No                                   | ❌ No                                   |
# | Used for                    | Utility functions related to class     | Factory methods or class-level changes |
# | How to call                 | `ClassName.method()` or `obj.method()` | `ClassName.method()` or `obj.method()` |
#
# 23. How does polymorphism work in Python with inheritance?
#
# -> polymorphism is one of the core principles of Object-Oriented Programming (OOP), and in Python, it works beautifully with inheritance.
#
# Let’s break it down step by step 👇
#
# 🧠 Meaning of Polymorphism
#
# The word polymorphism means “many forms.”
# In OOP, polymorphism allows different classes to define methods with the same name, but possibly with different behaviors.
#
# This means you can call the same method on different objects, and each object will respond in its own way.
#
# 24. What is method chaining in Python OOP?
#
# -> Method chaining in Python OOP means calling multiple methods on the same object in a single line, one after another — just like a “chain.”
# Each method returns the object itself (usually self), so that the next method can be called on it immediately.
#
# 🧩 Simple Definition:
#
# Method chaining allows multiple method calls on the same object in a single statement, by having each method return self.
#
#
# 25. What is the purpose of the __call__ method in Python?
#
# -> The __call__ method in Python is a special (dunder) method that allows an object of a class to be called like a function.
#
# In simple terms: if a class defines __call__, you can “call” its instances using parentheses () just like a regular function.
#
# 🧠 Purpose of __call__:
#
# . Makes objects callable.
#
# . Useful for creating function-like objects.
#
# . Can maintain state across calls (unlike regular functions).

# %% [markdown]
#                           **Practical Questions**

# %%
# 1.Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
 # that overrides the speak() method to print "Bark!".


# Parent class
class Animal:
    def speak(self):
        print("Animal makes a sound")  # Generic message

# Child class
class Dog(Animal):
    def speak(self):
        print("Bark!")  # Overridden method

# Creating objects
animal = Animal()
dog = Dog()

# Calling methods
animal.speak()  # Output: Animal makes a sound
dog.speak()     # Output: Bark!
# Out:
# Animal makes a sound
# Bark!

# %%
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass  # Abstract method

# Circle class
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

# Rectangle class
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Create objects
c = Circle(5)
r = Rectangle(4, 6)

# Display areas
print(f"Circle area: {c.area():.2f}")      # Circle area: 78.54
print(f"Rectangle area: {r.area():.2f}")   # Rectangle area: 24.00
# Out:
# Circle area: 78.54
# Rectangle area: 24.00

# %%
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.



# Parent class
class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

    def show_type(self):
        print(f"Vehicle type: {self.type}")

# Child class
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)  # Call Vehicle constructor
        self.brand = brand

    def show_brand(self):
        print(f"Car brand: {self.brand}")

# Grandchild class
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery):
        super().__init__(vehicle_type, brand)  # Call Car constructor
        self.battery = battery

    def show_battery(self):
        print(f"Battery capacity: {self.battery} kWh")

# Creating object of ElectricCar
tesla = ElectricCar("Car", "Tesla", 100)

# Accessing attributes and methods
tesla.show_type()     # Vehicle type: Car
tesla.show_brand()    # Car brand: Tesla
tesla.show_battery()  # Battery capacity: 100 kWh
# Out:
# Vehicle type: Car
# Car brand: Tesla
# Battery capacity: 100 kWh

# %%
# 4.Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.


# Base class
class Bird:
    def fly(self):
        print("Bird is flying")

# Derived class 1
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high and fast")

# Derived class 2
class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly, but swims")

# Creating objects
bird = Bird()
sparrow = Sparrow()
penguin = Penguin()

# Polymorphism in action
birds = [bird, sparrow, penguin]

for b in birds:
    b.fly()
# Out:
# Bird is flying
# Sparrow flies high and fast
# Penguin cannot fly, but swims

# %%
# 5. . Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

class BankAccount:
    def __init__(self, initial_balance):
        self.__balance = initial_balance  # Private attribute

    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}")
        else:
            print("Invalid deposit amount")

    # Method to withdraw money
    def withdraw(self, amount):
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: {amount}")
        else:
            print("Insufficient balance or invalid amount")

    # Method to check balance
    def check_balance(self):
        print(f"Current balance: {self.__balance}")

# Creating a bank account
account = BankAccount(1000)

# Using the encapsulated methods
account.check_balance()  # Current balance: 1000
account.deposit(500)     # Deposited: 500
account.withdraw(200)    # Withdrawn: 200
account.check_balance()  # Current balance: 1300

# Trying to access private attribute directly (will raise error)
# print(account.__balance)  # AttributeError
# Out:
# Current balance: 1000
# Deposited: 500
# Withdrawn: 200
# Current balance: 1300

# %%
# 6.Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().


# Base class
class Instrument:
    def play(self):
        print("Instrument is playing")

# Derived class 1
class Guitar(Instrument):
    def play(self):
        print("Guitar is strumming chords")

# Derived class 2
class Piano(Instrument):
    def play(self):
        print("Piano is playing a melody")

# Creating objects
inst = Instrument()
guitar = Guitar()
piano = Piano()

# Runtime polymorphism in action
instruments = [inst, guitar, piano]

for instr in instruments:
    instr.play()
# Out:
# Instrument is playing
# Guitar is strumming chords
# Piano is playing a melody

# %%
# 7.Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

class MathOperations:

    # Class method
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    # Static method
    @staticmethod
    def subtract_numbers(a, b):
        return a - b


# Using the class method
result_add = MathOperations.add_numbers(10, 5)
print("Addition:", result_add)

# Using the static method
result_sub = MathOperations.subtract_numbers(10, 5)
print("Subtraction:", result_sub)
# Out:
# Addition: 15
# Subtraction: 5

# %%
# 8.  Implement a class Person with a class method to count the total number of persons created.


class Person:
    count = 0   # Class variable to count total persons

    def __init__(self, name):
        self.name = name
        Person.count += 1   # Increment count whenever a new object is created

    @classmethod
    def total_persons(cls):
        return cls.count    # Returns total number of Person objects


# Creating Person objects
p1 = Person("Aditya")
p2 = Person("Rahul")
p3 = Person("Sneha")

# Using class method to get total persons
print("Total persons created:", Person.total_persons())
# Out:
# Total persons created: 3

# %%
# 9.Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


# Creating objects
f1 = Fraction(3, 4)
f2 = Fraction(7, 9)

# Printing fractions
print(f1)   # Output: 3/4
print(f2)   # Output: 7/9
# Out:
# 3/4
# 7/9

# %%
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Operator overloading for +
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"


# Creating vector objects
v1 = Vector(2, 3)
v2 = Vector(4, 1)

# Adding vectors using overloaded +
v3 = v1 + v2

print("Vector 1:", v1)
print("Vector 2:", v2)
print("Resultant Vector:", v3)
# Out:
# Vector 1: (2, 3)
# Vector 2: (4, 1)
# Resultant Vector: (6, 4)

# %%
# 11. 1. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")


# Example
p1 = Person("Aditya", 20)
p1.greet()
# Out:
# Hello, my name is Aditya and I am 20 years old.

# %%
# 12.  Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.

class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # list of numbers

    def average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)


# Example
s1 = Student("Aditya", [85, 90, 78, 92])
print("Average Grade:", s1.average_grade())
# Out:
# Average Grade: 86.25

# %%
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.

class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


# Example
r = Rectangle()
r.set_dimensions(10, 5)
print("Area of Rectangle:", r.area())

# %%
# 14. . Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.


class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus


# Example
e1 = Employee(40, 200)
print("Employee Salary:", e1.calculate_salary())

m1 = Manager(40, 200, 5000)
print("Manager Salary:", m1.calculate_salary())
# Out:
# Employee Salary: 8000
# Manager Salary: 13000

# %%
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity


# Example
p1 = Product("Laptop", 50000, 2)
print("Total Price:", p1.total_price())
# Out:
# Total Price: 100000

# %%
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass


class Cow(Animal):
    def sound(self):
        return "Moo"


class Sheep(Animal):
    def sound(self):
        return "Baa"


# Example
c = Cow()
s = Sheep()

print("Cow sound:", c.sound())
print("Sheep sound:", s.sound())
# Out:
# Cow sound: Moo
# Sheep sound: Baa

# %%
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"


# Example
b1 = Book("Atomic Habits", "James Clear", 2018)
print(b1.get_book_info())
# Out:
# 'Atomic Habits' by James Clear, published in 2018

# %%
# 18. 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price


class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms


# Example
m1 = Mansion("123 Luxury Street", 50000000, 12)

print("Address:", m1.address)
print("Price:", m1.price)
print("Number of Rooms:", m1.number_of_rooms)
# Out:
# Address: 123 Luxury Street
# Price: 50000000
# Number of Rooms: 12
